# %% [markdown]
# # 🔹 Q1 Aik variable a banao jisme value 20 ho, aur aik variable b banao jisme value 5 ho. In dono ko divide karo aur result print karo.

# %%
# type your code here

# %%
a = 20

# %%
b = 5

# %%
c = a/b

# %%
#YOU CAN DIRECTLY PRINT LIKE THIS BECAUSE IT'S JUPYTER NOTEBOOK BUT BELOW I SHOW YOU THE ORIGINAL METHOD.
c
# Out:
# 4.0

# %%
print(c)
# Out:
# 4.0

# %%
#WE CAN DO ALL STEPS IN ON STEP AS WELL
A = 20
B = 5
A/B
# Out:
# 4.0

# %% [markdown]
# # 🔹 Q2 Aik variable name banao jisme apna naam likho. Usay print karo aur uska lower case bhi print karo.

# %%
# type your code here

# %%
name = 'S.M TAHA HASSAN SHAH'

# %%
print(name)
# Out:
# S.M TAHA HASSAN SHAH

# %%
name.lower()
# Out:
# 's.m taha hassan shah'

# %% [markdown]
# # 🔹 Q3 Aik string likho: "hello world from python" Isay aise print karo ke har word ka pehla letter capital ho.

# %%
# type your code here

# %%
sent = "hello world from python"

# %%
print(sent)
# Out:
# hello world from python

# %%
sent.title()
# Out:
# 'Hello World From Python'

# %% [markdown]
# # 🔹 Q4 Aik variable x = 10 aur y = 3 banao. Inka modulus (%) nikaal kar print karo.

# %%
# type your code here

# %%
x = 10

# %%
y = 3

# %%
c = x%y

# %%
c
# Out:
# 1

# %%
#OR YOU CAN PRINT WITH OLD STYLE AS WELL
print(c)
# Out:
# 1

# %%
#WE CAN DO ALL STEPS IN ON STEP AS WELL
X = 10
Y = 3
X % Y
# Out:
# 1

# %% [markdown]
# # 🔹 Q5 Aik variable text = "PYTHON" banao. Isay lower case mai convert karke print karo

# %%
# type your code here

# %%
text = "PYTHON"

# %%
print(text)
# Out:
# PYTHON

# %%
text.lower()
# Out:
# 'python'

# %% [markdown]
# # 🔹 Q6 Aik string "data science" likho. Iski length nikaal kar print karo

# %%
# type your code here

# %%
dt = "data science"

# %%
len(dt)
# Out:
# 12

# %%
# PRINT WITH OLD ETHOD AS WELL
print(len(dt))
# Out:
# 12

# %%
#WE CAN DO ALL STEPS IN ON STEP AS WELL
len("data science")

# %% [markdown]
# # 🔹 Q7 Aik variable num = 7 banao. Iska square (power) nikaal kar print karo.

# %%
# type your code here

# %%
num = 7

# %%
#YOU CAN USE IN BUILT FUNCTION 
pow(num, 2)
# Out:
# 49

# %%
#YOU CAN USE IN BUILT FUNCTION (PRINT WITH PRINT FUNCTION)
print(pow(num, 2))
# Out:
# 49

# %%
#OR YOU CAN USE OLD STYLE METHOD
print(num ** 2)
# Out:
# 49

# %% [markdown]
# # 🔹 Q8 Aik string "hello" likho. Isay 3 dafa repeat karke print karo.

# %%
# type your code here

# %%
sentence = "hello"

# %%
#YOU CAN USE THAT AS WELL BUT GOOD APPROACH IS LOOP
print(sentence*3)
# Out:
# hellohellohello

# %%
for i in range(3):
    print(sentence, end = "")
# Out:
# hellohellohello

# %% [markdown]
# # 🔹 Q9 Aik variable a = 15 aur b = 10 banao. Check karo ke a bara hai b se ya nahi aur result print karo

# %%
# type your code here

# %%
a = 15

# %%
b = 10

# %%
c = a > b

# %%
c
# Out:
# True

# %%
print(c)
# Out:
# True

# %% [markdown]
# # 🔹 Q10 Aik string "i love python programming" likho. Isay aise print karo ke pehla letter capital ho (sirf first letter).

# %%
# type your code here

# %%
sent2 = "i love python programming"

# %%
print(sent2)
# Out:
# i love python programming

# %%
sent2.capitalize()
# Out:
# 'I love python programming'
