# %% [markdown]
# ## Create a string s containing your full name. Print the string.

# %%
s  = "Syed Muhammad Taha Hassan Shah"
s
# Out:
# 'Syed Muhammad Taha Hassan Shah'

# %%
#SECOND METHOD USING PRINT FNC
print(s)
# Out:
# Syed Muhammad Taha Hassan Shah

# %% [markdown]
# ## Create a string s with a sentence of your choice and print its length.

# %%
s1 = "Requirements Engineering (RE) is a fundamental part of Software Engineering that focuses on identifying, understanding, documenting, and managing the needs of stakeholders for a software system. It acts as the foundation of any successful project because clearly defined requirements guide the entire development process. Without proper requirements, software projects often face issues such as delays, increased costs, or failure to meet user expectations."
len(s1)
# Out:
# 457

# %% [markdown]
# ## Assign a string to a variable and check its data type using Python

# %%
s2 = "Requirements Engineering (RE) is a fundamental part of Software Engineering."
type(s2)
# Out:
# str

# %% [markdown]
# ## Create a variable word with the value "Python" and print the first character.

# %%
word = "Python"
word[0]
# Out:
# 'P'

# %% [markdown]
# ## Create a variable course with the value "Python" and print the character at index 3.

# %%
course = "Python"
course[3]
# BECAUSE INDEXING START FROM 0. ON 0 INDEX IT P THEN ON 1 IT'S Y, ON 2 INDEX IT'S T AND ON 3RD H IS THERE.
# Out:
# 'h'

# %% [markdown]
# ## Create a variable framework with the value "TensorFlow" and print the character at negative index -4.

# %%
framework = "TensorFlow"
framework[-4]
#IN REVERSE INDEXING INDEXING START FROM -1 NOT FROM 0.
# Out:
# 'F'

# %% [markdown]
# ## Create a variable fruit with the value "Apple". Convert the string to uppercase and print it.

# %%
fruit = "Apple"
fruit.upper()
# Out:
# 'APPLE'

# %% [markdown]
# ## Create a variable city with the value "Karachi". Convert the string to lowercase and print it.

# %%
city = "KaRaChi"
city.lower()
# Out:
# 'karachi'

# %% [markdown]
# ## Create a variable framework with the value "Django". Check if the string starts with "D" and print True or False.

# %%
framework = "Django"
framework.startswith("D")
# Out:
# True

# %% [markdown]
# ## Create a variable subject with the value "Mathematics". Check if all characters are alphabetic and print True or False.

# %%
subject = "Mathematics"
subject.isalpha()
# Out:
# True

# %% [markdown]
# ## Ask the user to enter their email in any format.
# ## and then Convert it into lowercase.

# %%
email = input("Enter Your Email: ")
email.lower()
